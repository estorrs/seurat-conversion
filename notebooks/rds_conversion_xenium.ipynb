# %%
library(Seurat)
library(SeuratDisk)
# Out:
# The legacy packages maptools, rgdal, and rgeos, underpinning this package
# will retire shortly. Please refer to R-spatial evolution reports on
# https://r-spatial.org/r/2023/05/15/evolution4.html for details.
# This package is now running under evolution status 0
#
# Attaching SeuratObject
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat

# %%
saveH5ad <- function(obj, h5_fp, assay='RNA') {
    for (col in colnames(obj@meta.data)) {
        if (!is.null(as.numeric(as.character(obj[[col]][1])))) {
            obj@meta.data[[col]] = as.character(obj@meta.data[[col]])
        }
    }
    SaveH5Seurat(obj, filename = h5_fp, overwrite = T)
    Convert(h5_fp, dest = "h5ad", overwrite = T, assay=assay)
}

# %%
# input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/ccRCC/ccRCC_reference_xenium_snvs_v1.rds'
# output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/ccrcc_rna.h5seurat'

# input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/GBM/GBM_reference_xenium_snvs_v1.rds'
# output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/gbm_rna.h5seurat'

# input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/CRC/CRC_reference_xenium_snvs_v1.rds'
# output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/crc_rna.h5seurat'

# input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/MM/MM_reference_xenium_snvs_v1.rds'
# output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/mm_rna.h5seurat'

# input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/PDAC/PDAC_reference_xenium_snvs_v1.rds'
# output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/pdac_rna.h5seurat'

input_fp = '/diskmnt/Projects/Users/austins2/tools/xenium_snvs/version_4/cnv_expression_references/BRCA/BRCA_reference_xenium_snvs_v1.rds'
output_fp = '/diskmnt/Projects/Users/estorrs/sandbox/austin_xenium/brca_rna.h5seurat'

# %%
obj = readRDS(input_fp)
obj
# Out:
# An object of class Seurat
# 63577 features across 18685 samples within 2 assays
# Active assay: SCT (26976 features, 3000 variable features)
#  1 other assay present: RNA
#  2 dimensional reductions calculated: pca, umap.30PC

# %%
head(obj@assays$RNA@counts)
# Out:
#   [[ suppressing 34 column names ‘HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AACAACCCAGTGTATC-1’, ‘HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_ACGGTTACACCCTCTA-1’, ‘HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGACACTTCGACCATA-1’ ... ]]
# 6 x 18685 sparse Matrix of class "dgCMatrix"
#
# MIR1302-2HG . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# FAM138A     . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# OR4F5       . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# AL627309.1  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# AL627309.3  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# AL627309.2  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# MIR1302-2HG ......
# FAM138A     ......
# OR4F5       ......
# AL627309.1  ......
# AL627309.3  ......
# AL627309.2  ......
#
#  .....suppressing 18651 columns in show(); maybe adjust 'options(max.print= *, width = *)'
# ...

# %%
head(obj@meta.data)
# Out:
#                                                               orig.ident
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AACAACCCAGTGTATC-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_ACGGTTACACCCTCTA-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGACACTTCGACCATA-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGCGATTCAACCTATG-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGCTACATCCTCAGAA-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGGATCTGTGAACTAA-1 HT206B1-S1H4A2Y1_1N1Z1_1B1
#                                                               nCount_RNA
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AACAACCCAGTGTATC-1  5510
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_ACGGTTACACCCTCTA-1  1036
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGACACTTCGACCATA-1 13777
# HTAN_BRCA_snRNA_HT206B1-S1H4A2Y1_1N1Z1_1B1_AGCGATTCAACCTATG-1 10664
# ...

# %%
# DefaultAssay(object = obj) <- "SCT"
# slim <- DietSeurat(obj, assay = 'SCT')
# # slot(slim$SCT@SCTModel.list[[1]], 'median_umi') = median(slim$SCT@SCTModel.list[[1]]@cell.attributes$umi)
# # slot(slim$SCT@SCTModel.list[[2]], 'median_umi') = median(slim$SCT@SCTModel.list[[2]]@cell.attributes$umi)
# saveH5ad(
#     slim, assay='SCT',
#     '/diskmnt/Projects/Users/estorrs/sandbox/xenium_single_cell_mouse/brca_sct.h5seurat')

DefaultAssay(object = obj) <- "RNA"
slim <- DietSeurat(obj, assay = 'RNA')
saveH5ad(slim, assay='RNA', output_fp)
# Out:
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# Warning message in saveH5ad(slim, assay = "RNA", output_fp):
# “NAs introduced by coercion”
# ...

# %%
# obj = readRDS(
#     '/diskmnt/Projects/Users/rliu/Projects/normal_mouse_kidney_development/snRNA_ATAC_combo/sample_integration_RNA_ATAC_merged/NMK_E16.5X2_P0X2_W3X3_W12X3_W52X3_W92X3_20230228_doublet_removed/results/snRNA_ATAC_jointly_analyzed_for_NMK_E16.5X2_P0X2_W3X3_W12X3_W52X3_W92X3_20230228_doublet_removed.rds')

# DefaultAssay(object = obj) <- "SCT"
# slim <- DietSeurat(obj, assay = 'SCT')
# slot(slim$SCT@SCTModel.list[[1]], 'median_umi') = median(slim$SCT@SCTModel.list[[1]]@cell.attributes$umi)
# # slot(slim$SCT@SCTModel.list[[2]], 'median_umi') = median(slim$SCT@SCTModel.list[[2]]@cell.attributes$umi)
# saveH5ad(
#     slim, assay='SCT',
#     '/diskmnt/Projects/Users/estorrs/sandbox/xenium_single_cell/kidney_sct.h5seurat')

# DefaultAssay(object = obj) <- "RNA"
# slim <- DietSeurat(obj, assay = 'RNA')
# saveH5ad(
#     slim, assay='RNA',
#     '/diskmnt/Projects/Users/estorrs/sandbox/xenium_single_cell/kidney_rna.h5seurat')
